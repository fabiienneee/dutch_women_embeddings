# %% [markdown]
# # This notebook preprocesses a csv file containing texts from newspapers for a word embedding model

# %%
## Import packages
#!pip install --upgrade pandas
import pandas as pd
from google.colab import drive

# !pip install ftfy
import ftfy
from ftfy import fix_and_explain, apply_plan, fix_text

import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
nltk.download("punkt")
nltk.download('stopwords')

from itertools import chain
# Out:
# Collecting ftfy
#   Downloading https://files.pythonhosted.org/packages/ce/b5/5da463f9c7823e0e575e9908d004e2af4b36efa8d02d3d6dad57094fcb11/ftfy-6.0.1.tar.gz (63kB)
#      |████████████████████████████████| 71kB 3.5MB/s
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from ftfy) (0.2.5)
# Building wheels for collected packages: ftfy
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.1-cp37-none-any.whl size=41573 sha256=3c11fcbf750afb63bf6e61b9889d97eb2b109b9991ce0e0e1e6e2b3f92c28c67
#   Stored in directory: /root/.cache/pip/wheels/ae/73/c7/9056e14b04919e5c262fe80b54133b1a88d73683d05d7ac65c
# Successfully built ftfy
# Installing collected packages: ftfy
# Successfully installed ftfy-6.0.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
## Mount drive
drive.mount('/content/drive')

## Load data
data_path = 'path to data folder'
file_name = '1792_1870' # Change here to preprocess a different time period
extension = '.zip'
df = pd.read_csv(data_path+file_name+extension, encoding='latin1', parse_dates=['date'])
# Out:
# Mounted at /content/drive

# %%
# View data
print(df.info())
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200984 entries, 0 to 200983
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  200984 non-null  int64
#  1   index       200984 non-null  int64
#  2   identifier  200984 non-null  object
#  3   type        200984 non-null  object
#  4   title       200951 non-null  object
#  5   papertitle  200984 non-null  object
#  6   date        200984 non-null  datetime64[ns]
#  7   text        200983 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 12.3+ MB
# None
#    Unnamed: 0  ...                                               text
# 0           0  ...  In onze stadscourant las ik dezer dagen het vo...
# 1           1  ...  â De Rott. CL, die op het punt der vrouw zee...
# 2           2  ...  Is het plan der medische volmakingsschool niet...
# 3           3  ...  Vergun aan eenen uwer meest bestendige lezers,...
# 4           4  ...  In de Revue de Paris leest men: Â»'t Kijk van ...
# 5           5  ...  obstetriiiee , en, dames hebben er geen zittin...
# 6           6  ...  GEEN VROUWEN-EMANCIPATIE? EEN WOORD AAN Mevrou...
# 7           7  ...  Bij den Uitgever P. J. MILBORN te Middelburg, ...
# 8           8  ...  Op 27 Julij 11. slond zekere John Aylesfort vo...
# 9           9  ...  gen 'klaagt over den invloed, dien de franjche...
#
# [10 rows x 8 columns]

# %%
## remove duplicate entries based on the text column
df = df.drop_duplicates(subset=['text'])

## remove unnecessary columns
df = df.drop(['Unnamed: 0', 'identifier'], axis=1, errors='ignore')

## reset the index
df = df.reset_index()
print(df.info())

## check for NA in text & drop
print("NA values in text:",df['text'].isna().any())
print(type(df))
df = df.dropna(axis=0, how='any', subset=['text'])
print("NA values in text:",df['text'].isna().any())
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200984 entries, 0 to 200983
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   level_0     200984 non-null  int64
#  1   index       200984 non-null  int64
#  2   type        200984 non-null  object
#  3   title       200951 non-null  object
#  4   papertitle  200984 non-null  object
#  5   date        200984 non-null  datetime64[ns]
#  6   text        200983 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 10.7+ MB
# None
# NA values in text: True
# <class 'pandas.core.frame.DataFrame'>
# NA values in text: False
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200983 entries, 0 to 200983
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   level_0     200983 non-null  int64
#  1   index       200983 non-null  int64
#  2   type        200983 non-null  object
#  3   title       200950 non-null  object
#  4   papertitle  200983 non-null  object
#  5   date        200983 non-null  datetime64[ns]
#  6   text        200983 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 12.3+ MB
# None

# %%
# View one text
df['text'][10]
# Out:
# 'Onder bovenstaand opschrift bevat de Arnli. Ct. het volgende ingezonden stuk:. â\x80¢ Â« Vergun aan eeneu ; uwer meest, bestendige lezers , mijnheer de redacteur, u de redenen \'op te geven , Waarom hij\'; niet. kan instemmen met hetgeen gij ia "uw nummer, vau 15 Augustus geschreven liebt over de Â» emancipatie der vrouw" Â» In de perste plaats , is dat grootsch klinkende woord emancipatie hier wel goed , gekozen ? ~ Ik geloof het niet. Al kennen wij ome vrouwen geeue politieke regten toe, al roepen wij , haar Â«iet in : de raadzaal en in de pleitzaal, â\x80\x9e wij beschouwen en behandelen haar daarom niÃ©t â\x96\xa0 als slaven, lijfeigenen, minderjarigen of onnouzelen. Do â\x80¢ invloed der vrouw is in onze maatschappij zeer sterkt niet enkel iu het huiselijke, raam\' ook in het publieke , in het gansche maatschappelijk leven.,-, eu naar mijne overtuiging, is die invloed der vrouw op en in onze maatschappij juist daarom zoo sterk, omdat hij een moreele, d. i. een .middellijk werkende , invloed is. Ã¯xDe.eisch der gelijkstelling van de vrouw met den man rust op de grondstelling of\'elgenlijk op de onderstelling, dat de vrouw in alles de gelijke van den man en zijn evÃ©ubeeld is, en dat dus de uitsluitende toekenning aan de mannen van zekere reg ten en der uitoefening van zekere bedrijven, eene willekeurige uit vooroordeel ontstane en in stand gehouden bepaling is. i Â» Deze voorstelling is , 111. i., geheel onjuist, omdat de grondstelling en onderstelling op welke zij rust insgelijks onjuist is. De.vrouw is wel degelijk van eene andere natuur dan de man en een niet enkel physisch maar ook psychisch van hem verschillend wezen. Ik beweer daarmede geenszins dat de vrouw de mindere van den man is, dat zij verstandelijk beneden hein staat en niet voor dezelfde intellectueelo ontwikkeling als hij vatbaar is. Ik beweer enkel dit , dat de man en de vrouw wel hoinogeene maar toch van natuur verschillende wezens zijn, wezens, die, elk met een bijzonderen aanleg en eene bijzondere roeping, hunne eigenaardige taak in het leven te vervullen hebben. De groote staats-econoimsche wet der zatncnwerkiiig door verdeclinri van den arbeid, is ook dc groote natuur economische wet, de wet die evenzeer de hoogste diersoort â\x80\x94den mensehâ\x80\x94als alle andere diersoorten belieerscht. Door hare eigen*- aardige vrouwelijke hoedanigheden wordt evenzeer de werkkring der vrouw, als door zijne eigenaardige mannelijke hoedanigheden die van den man bepaald. En voor de vrouw is die werkkring zeer duidelijk aangewezen: het huisselijke en particuliere leven, het leven van.de huisvrouw en de huismoeder. Als vriendin, raadgeefster, helpster van don man , niet als zijn gelijke en mededingster, werkt zij met hem tot het gemeenschappelijk doel des levens zamen. Is zij daarom Vlinder dan de man, omdat zij niet op de beurs handelt, niet vonnissen helpt wijzen en wetteu maken, geen chirurgicale operalien doet, geeno legers aanvoert en geene vloten kommandccrt ? Â» Aan de vrouwen politieke regten te willen toekennen eu haar in de raadzaal en in de pleitzaal te roGpen , omdat de mannen politieke regten hebben en in die zalen optreden, is, dunkt mij, eene onlogische en valsche gelijkheids - theorie. Do toekenning dier reglcn kan ook voor de vrouwen alleen gemotiveerd worden door hetzelfde motiet waardoor het bij de mannen gemotiveerd wordt: door de eisohen van het publiek belang. Een publiek regt behoort niet te worden toegekend om de personen te believen aan wie men het toekent, maar omdat het algemeen belang die toekenning aan deze personen eischt. Eene uitbreiding van het stemregt b. v. is alleen dan gemotiveerd , wanneer men aantoont, dat \'in het algemeen belang nieuwe categorien van kiezers aan de beslaande JBehooren toegevoegd te worden. ii Op dit standpunt moet men zich plaatsen om bet onderwerp van de zoogenaamde Â» emancipatie" der vrouw juist te kunnen beoordeelen. Is do regtstreeksche deelneming der vrouwen aan hetâ\x80¢ publiek leven een eisch van al ...

# %%
## Fix encoding issues
for index, row in df.iterrows():
  text = row['text']
  text_fixed = fix_text(text)
  df.loc[index, 'text'] = text_fixed

# Check one text
df['text'][10]
# Out:
# 'Onder bovenstaand opschrift bevat de Arnli. Ct. het volgende ingezonden stuk:. • « Vergun aan eeneu ; uwer meest, bestendige lezers , mijnheer de redacteur, u de redenen \'op te geven , Waarom hij\'; niet. kan instemmen met hetgeen gij ia "uw nummer, vau 15 Augustus geschreven liebt over de » emancipatie der vrouw" » In de perste plaats , is dat grootsch klinkende woord emancipatie hier wel goed , gekozen ? ~ Ik geloof het niet. Al kennen wij ome vrouwen geeue politieke regten toe, al roepen wij , haar «iet in : de raadzaal en in de pleitzaal, " wij beschouwen en behandelen haar daarom niét ■ als slaven, lijfeigenen, minderjarigen of onnouzelen. Do • invloed der vrouw is in onze maatschappij zeer sterkt niet enkel iu het huiselijke, raam\' ook in het publieke , in het gansche maatschappelijk leven.,-, eu naar mijne overtuiging, is die invloed der vrouw op en in onze maatschappij juist daarom zoo sterk, omdat hij een moreele, d. i. een .middellijk werkende , invloed is. ïxDe.eisch der gelijkstelling van de vrouw met den man rust op de grondstelling of\'elgenlijk op de onderstelling, dat de vrouw in alles de gelijke van den man en zijn evéubeeld is, en dat dus de uitsluitende toekenning aan de mannen van zekere reg ten en der uitoefening van zekere bedrijven, eene willekeurige uit vooroordeel ontstane en in stand gehouden bepaling is. i » Deze voorstelling is , 111. i., geheel onjuist, omdat de grondstelling en onderstelling op welke zij rust insgelijks onjuist is. De.vrouw is wel degelijk van eene andere natuur dan de man en een niet enkel physisch maar ook psychisch van hem verschillend wezen. Ik beweer daarmede geenszins dat de vrouw de mindere van den man is, dat zij verstandelijk beneden hein staat en niet voor dezelfde intellectueelo ontwikkeling als hij vatbaar is. Ik beweer enkel dit , dat de man en de vrouw wel hoinogeene maar toch van natuur verschillende wezens zijn, wezens, die, elk met een bijzonderen aanleg en eene bijzondere roeping, hunne eigenaardige taak in het leven te vervullen hebben. De groote staats-econoimsche wet der zatncnwerkiiig door verdeclinri van den arbeid, is ook dc groote natuur economische wet, de wet die evenzeer de hoogste diersoort —den menseh—als alle andere diersoorten belieerscht. Door hare eigen*- aardige vrouwelijke hoedanigheden wordt evenzeer de werkkring der vrouw, als door zijne eigenaardige mannelijke hoedanigheden die van den man bepaald. En voor de vrouw is die werkkring zeer duidelijk aangewezen: het huisselijke en particuliere leven, het leven van.de huisvrouw en de huismoeder. Als vriendin, raadgeefster, helpster van don man , niet als zijn gelijke en mededingster, werkt zij met hem tot het gemeenschappelijk doel des levens zamen. Is zij daarom Vlinder dan de man, omdat zij niet op de beurs handelt, niet vonnissen helpt wijzen en wetteu maken, geen chirurgicale operalien doet, geeno legers aanvoert en geene vloten kommandccrt ? » Aan de vrouwen politieke regten te willen toekennen eu haar in de raadzaal en in de pleitzaal te roGpen , omdat de mannen politieke regten hebben en in die zalen optreden, is, dunkt mij, eene onlogische en valsche gelijkheids - theorie. Do toekenning dier reglcn kan ook voor de vrouwen alleen gemotiveerd worden door hetzelfde motiet waardoor het bij de mannen gemotiveerd wordt: door de eisohen van het publiek belang. Een publiek regt behoort niet te worden toegekend om de personen te believen aan wie men het toekent, maar omdat het algemeen belang die toekenning aan deze personen eischt. Eene uitbreiding van het stemregt b. v. is alleen dan gemotiveerd , wanneer men aantoont, dat \'in het algemeen belang nieuwe categorien van kiezers aan de beslaande JBehooren toegevoegd te worden. ii Op dit standpunt moet men zich plaatsen om bet onderwerp van de zoogenaamde » emancipatie" der vrouw juist te kunnen beoordeelen. Is do regtstreeksche deelneming der vrouwen aan het• publiek leven een eisch van algemeen belang? Met andere woorden: wordt het algemeen bel ...

# %%
## Tokenization white-space

# Tokenize to sentences
df['sen_tokenized'] = df.apply(lambda row: nltk.sent_tokenize(row['text'], language="dutch"), axis=1)

# Tokenize to words with white-space
tokenizer = RegexpTokenizer(r'\w+')
tokenized = []
for index, row in df.iterrows():
  sent = row['sen_tokenized']
  tokens = [tokenizer.tokenize(sentence) for sentence in sent]
  tokenized.append(tokens)

df['tokenized'] = tokenized

# Make a new column with the length of each tokenized article
df['length'] = df.apply(lambda row: sum([len(x) for x in row['tokenized']]), axis=1)

# Check the total amount of tokens
print("Total tokens data-set: ",sum(df['length']))

# Check one text
df['tokenized'][10]
# Out:
# Total tokens data-set:  118449415
# [['Onder', 'bovenstaand', 'opschrift', 'bevat', 'de', 'Arnli'],
#  ['Ct'],
#  ['het', 'volgende', 'ingezonden', 'stuk'],
#  ['Vergun',
#   'aan',
#   'eeneu',
#   'uwer',
#   'meest',
#   'bestendige',
#   'lezers',
#   'mijnheer',
#   'de',
#   'redacteur',
#   'u',
#   'de',
#   'redenen',
#   'op',
#   'te',
#   'geven',
#   'Waarom',
#   'hij',
#   'niet'],
#  ['kan',
#   'instemmen',
#   'met',
#   'hetgeen',
#   'gij',
#   'ia',
#   'uw',
#   'nummer',
#   'vau',
#   '15',
#   'Augustus',
#   'geschreven',
#   'liebt',
#   'over',
#   'de',
#   'emancipatie',
#   'der',
#   'vrouw',
#   'In',
#   'de',
#   'perste',
#   'plaats',
#   'is',
#   'dat',
#   'grootsch',
#   'klinkende',
#   'woord',
#   'emancipatie',
#   'hier',
#   'wel',
#   'goed',
#   'gekozen'],
#  ['Ik', 'geloof', 'het', 'niet'],
#  ['Al',
#   'kennen',
#   'wij',
#   'ome',
#   'vrouwen',
#   'geeue',
#   'politieke',
#   'regten',
#   'toe',
#   'al',
#   'roepen',
#   'wij',
#   'haar',
#   'iet',
#   'in',
#   'de',
#   'raadzaal',
#   'en',
#   'in',
#   'de',
#   'pleitzaal',
#   'wij',
#   'beschouwen',
#   'en',
#   'behandelen',
#   'haar',
#   'daarom',
#   'niét',
#   'als',
#   'slaven',
#   'lijfeigenen',
#   'minderjarigen',
#   'of',
#   'onnouzelen'],
#  ['Do',
#   'invloed',
#   'der',
#   'vrouw',
#   'is',
#   'in',
#   'onze',
#   'maatschappij',
#   'zeer',
#   'sterkt',
#   'niet',
#   'enkel',
#   'iu',
#   'het',
#   'huiselijke',
#   'raam',
#   'ook',
#   'in',
#   'het',
#   'publieke',
#   'in',
#   'het',
#   'gansche',
#   'maatschappelijk',
#   'leven',
#   'eu',
#   'naar',
#   'mijne',
#   'overtuiging',
#   'is',
#   'die',
#   'invloed',
#   'der',
#   'vrouw',
#   'op',
#   'en',
#   'in',
#   'onze',
#   'maatschappij',
#   'juist',
#   'daarom',
#   'zoo',
#   'sterk',
#   'omdat',
#   'hij',
#   'een',
#   'moreele',
#   'd',
#   'i',
#   'een',
#   'middellijk',
#   'werkende',
#   'invloed',
#   'is'],
#  ['ïxDe',
#   'eisch',
#   'der',
#   'gelijkstelling',
#   'van',
#   'de',
#   'vrouw',
#   'met',
#   'den',
#   'man',
#   'rust',
#   'op',
#   'de',
#   'grondstelling',
#   'of',
#   'elgenlijk',
#   'op',
#   'de',
#   'onderstelling',
#   'dat',
#   'de',
#   'vrouw',
#   'in',
#   'alles',
#   'de',
#   'gelijke',
#   'van',
#   'den',
#   'man',
#   'en',
#   'zijn',
#   'evéubeeld',
#   'is',
#   'en',
#   'dat',
#   'dus',
#   'de',
#   'uitsluitende',
#   'toekenning',
#   'aan',
#   'de',
#   'mannen',
#   'van',
#   'zekere',
#   'reg',
#   'ten',
#   'en',
#   'der',
#   'uitoefening',
#   'van',
#   'zekere',
#   'bedrijven',
#   'eene',
#   'willekeurige',
#   'uit',
#   'vooroordeel',
#   'ontstane',
#   'en',
#   'in',
#   'stand',
#   'gehouden',
#   'bepaling',
#   'is'],
#  ['i',
#   'Deze',
#   'voorstelling',
#   'is',
#   '111',
#   'i',
#   'geheel',
#   'onjuist',
#   'omdat',
#   'de',
#   'grondstelling',
#   'en',
#   'onderstelling',
#   'op',
#   'welke',
#   'zij',
#   'rust',
#   'insgelijks',
#   'onjuist',
#   'is'],
#  ['De',
#   'vrouw',
#   'is',
#   'wel',
#   'degelijk',
#   'van',
#   'eene',
#   'andere',
#   'natuur',
#   'dan',
#   'de',
#   'man',
#   'en',
#   'een',
#   'niet',
#   'enkel',
#   'physisch',
#   'maar',
#   'ook',
#   'psychisch',
#   'van',
#   'hem',
#   'verschillend',
#   'wezen'],
#  ['Ik',
#   'beweer',
#   'daarmede',
#   'geenszins',
#   'dat',
#   'de',
#   'vrouw',
#   'de',
#   'mindere',
#   'van',
#   'den',
#   'man',
#   'is',
#   'dat',
#   'zij',
#   'verstandelijk',
#   'beneden',
#   'hein',
#   'staat',
#   'en',
#   'niet',
#   'voor',
#   'dezelfde',
#   'intellectueelo',
#   'ontwikkeling',
#   'als',
#   'hij',
#   'vatbaar',
#   'is'],
#  ['Ik',
#   'beweer',
#   'enkel',
#   'dit',
#   'dat',
#   'de',
#   'man',
#   'en',
#   'de',
#   'vrouw',
#   'wel',
#   'hoinogeene',
#   'maar',
#   'toch',
#   'van',
#   'natuur',
#   'verschillende',
#   'wezens',
#   'zijn',
#   'wezens',
#   'die',
#   'elk',
#   'met',
#   'een',
#   'bijzonderen',
#   'aanleg',
#   'en',
#   'eene',
#   'bijzondere',
#   'roeping',
#   'hunne',
#   'eigenaardige',
#   'taak',
#   'in',
#   'het',
#   'leven',
#   'te',
#   'vervullen',
#   'hebben'],
#  ['De',
#   'groote',
#   'staats',
#   'econoimsche',
#   'wet',
#   'der',
#   'zatncnwerkiiig',
#   'door',
#   'verdeclinri',
#   'van',
#   'den',
#   'arbeid',
#   'is',
#   'ook',
#   'dc',
#   'groote',
#   'natuur',
#   'economische',
#   'wet',
#   'de',
#   'wet',
#   'die',
#   'evenzeer',
#   'de',
#   'hoogste',
#   'diersoort',
#   'den',
#   'menseh',
#   'als',
#   'alle',
#   'andere',
#   'diersoorten',
#   'belieerscht'],
#  ['Door',
#   'hare',
#   'eigen',
#   'aardige',
#   'vrouwelijke',
#   'hoedanigheden',
#   'wordt',
#   'evenzeer',
#   'de',
#   'werkkring',
#   'der',
#   'vrouw',
#   'als',
#   'door',
#   'zijne',
#   'eigenaardige',
#   'mannelijke',
#   'hoedanigheden',
#   'die',
#   'van',
#   'den',
#   'man',
#   'bepaald'],
#  ['En',
#   'voor',
#   'de',
#   'vrouw',
#   'is',
#   'die',
#   'werkkring',
#   'zeer',
#   'duidelijk',
#   'aangewezen',
#   'het',
#   'huisselijke',
#   'en',
#   'particuliere',
#   'leven',
#   'het',
#   'leven',
#   'van',
#   'de',
#   'huisvrouw',
#   'en',
#   'de',
#   'huismoeder'],
#  ['Als',
#   'vriendin',
#   'raadgeefster',
#   'helpster',
#   'van',
#   'don',
#   'man',
#   'niet',
#   'als',
#   'zijn',
#   'gelijke',
#   'en',
#   'mededingster',
#   'werkt',
#   'zij',
#   'met',
#   'hem',
#   'tot',
#   'het',
#   'gemeenschappelijk',
#   'doel',
#   'des',
#   'levens',
#   'zamen'],
#  ['Is',
#   'zij',
#   'daarom',
#   'Vlinder',
#   'dan',
#   'de',
#   'man',
#   'omdat',
#   'zij',
#   'niet',
#   'op',
#   'de',
#   'beurs',
#   'handelt',
#   'niet',
#   'vonnissen',
#   'helpt',
#   'wijzen',
#   'en',
#   'wetteu',
#   'maken',
#   'geen',
#   'chirurgicale',
#   'operalien',
#   'doet',
#   'geeno',
#   'legers',
#   'aanvoert',
#   'en',
#   'geene',
#   'vloten',
#   'kommandccrt'],
#  ['Aan',
#   'de',
#   'vrouwen',
#   'politieke',
#   'regten',
#   'te',
#   'willen',
#   'toekennen',
#   'eu',
#   'haar',
#   'in',
#   'de',
#   'raadzaal',
#   'en',
#   'in',
#   'de',
#   'pleitzaal',
#   'te',
#   'roGpen',
#   'omdat',
#   'de',
#   'mannen',
#   'politieke',
#   'regten',
#   'hebben',
#   'en',
#   'in',
#   'die',
#   'zalen',
#   'optreden',
#   'is',
#   'dunkt',
#   'mij',
#   'eene',
#   'onlogische',
#   'en',
#   'valsche',
#   'gelijkheids',
#   'theorie'],
#  ['Do',
#   'toekenning',
#   'dier',
#   'reglcn',
#   'kan',
#   'ook',
#   'voor',
#   'de',
#   'vrouwen',
#   'alleen',
#   'gemotiveerd',
#   'worden',
#   'door',
#   'hetzelfde',
#   'motiet',
#   'waardoor',
#   'het',
#   'bij',
#   'de',
#   'mannen',
#   'gemotiveerd',
#   'wordt',
#   'door',
#   'de',
#   'eisohen',
#   'van',
#   'het',
#   'publiek',
#   'belang'],
#  ['Een',
#   'publiek',
#   'regt',
#   'behoort',
#   'niet',
#   'te',
#   'worden',
#   'toegekend',
#   'om',
#   'de',
#   'personen',
#   'te',
#   'believen',
#   'aan',
#   'wie',
#   'men',
#   'het',
#   'toekent',
#   'maar',
#   'omdat',
#   'het',
#   'algemeen',
#   'belang',
#   'die',
#   'toekenning',
#   'aan',
#   'deze',
#   'personen',
#   'eischt'],
#  ['Eene',
#   'uitbreiding',
#   'van',
#   'het',
#   'stemregt',
#   'b',
#   'v',
#   'is',
#   'alleen',
#   'dan',
#   'gemotiveerd',
#   'wanneer',
#   'men',
#   'aantoont',
#   'dat',
#   'in',
#   'het',
#   'algemeen',
#   'belang',
#   'nieuwe',
#   'categorien',
#   'van',
#   'kiezers',
#   'aan',
#   'de',
#   'beslaande',
#   'JBehooren',
#   'toegevoegd',
#   'te',
#   'worden'],
#  ['ii',
#   'Op',
#   'dit',
#   'standpunt',
#   'moet',
#   'men',
#   'zich',
#   'plaatsen',
#   'om',
#   'bet',
#   'onderwerp',
#   'van',
#   'de',
#   'zoogenaamde',
#   'emancipatie',
#   'der',
#   'vrouw',
#   'juist',
#   'te',
#   'kunnen',
#   'beoordeelen'],
#  ['Is',
#   'do',
#   'regtstreeksche',
#   'deelneming',
#   'der',
#   'vrouwen',
#   'aan',
#   'het',
#   'publiek',
#   'leven',
#   'een',
#   'eisch',
#   'van',
#   'algemeen',
#   'belang'],
#  ['Met',
#   'andere',
#   'woorden',
#   'wordt',
#   'het',
#   'algemeen',
#   'belang',
#   'piet',
#   'of',
#   'niet',
#   'folleilig',
#   'behartigd',
#   'wanneer',
#   'men',
#   'alleen',
#   'de',
#   'mannen',
#   'tot',
#   'reglstreeksche',
#   'deelneming',
#   'in',
#   'het',
#   'publiek',
#   'leven',
#   'reepte',
#   'Op',
#   'beide',
#   'vragen',
#   'antwoord',
#   'ik',
#   'ontkennend'],
#  ['B',
#   'vrouwen',
#   'iu',
#   'liet',
#   'publieke',
#   'leven',
#   'te',
#   'trekken',
#   'is',
#   'I',
#   'haart',
#   'onttrekken',
#   'aan',
#   'liet',
#   'h',
#   'uissel',
#   'ij',
#   'k',
#   'leven',
#   'is',
#   'y',
#   'haar',
#   'iriid'],
#  ['dellijke',
#   'morec',
#   'e',
#   'invloed',
#   'vervangen',
#   'door',
#   'ëëa',
#   'regt',
#   'treeksohen',
#   'imtcrieeleh',
#   'io',
#   'óe',
#   'l'],
#  ['En',
#   'hierin',
#   'zie',
#   'ik',
#   'een',
#   'groot',
#   'gevaar',
#   'voor',
#   'de',
#   'maatsebappij'],
#  ['De',
#   'vrouw',
#   'zal',
#   'daardoor',
#   'van',
#   'de',
#   'raad',
#   'geefster',
#   'des',
#   'mans',
#   'zijne',
#   'mededingster',
#   'worden',
#   'zij',
#   'zal',
#   'in',
#   'het',
#   'publieke',
#   'leven',
#   'even',
#   'dikwijls',
#   'tegen',
#   'hem',
#   'over',
#   'al',
#   'naast',
#   'hem',
#   'staan'],
#  ['Zij', 'zal', 'daardoor', 'aan'],
#  ['gezag',
#   'kunnen',
#   'winnen',
#   'maar',
#   'in',
#   'gelijke',
#   'mate',
#   'haren',
#   'invloed',
#   'op',
#   'hein',
#   'verliezen'],
#  ['Wanneer',
#   'de',
#   'vrouw',
#   'gelijk',
#   'thans',
#   'zelve',
#   'buiten',
#   'het',
#   'strijdperk',
#   'der',
#   'meeinngeu',
#   'slaat',
#   'is',
#   'haar',
#   'oordeel',
#   'over',
#   'hetgeen',
#   'daarin',
#   'voorvalt',
#   'meestal',
#   'een',
#   'objectiet',
#   'oordeel'],
#  ['Omdat',
#   'zij',
#   'geene',
#   'partij',
#   'in',
#   'het',
#   'geschil',
#   'is',
#   'beoordeelt',
#   'zij',
#   'de',
#   'laken',
#   'dikwijls',
#   'onzijdigcr',
#   'dan',
#   'wij',
#   'strijdvoerende',
#   'partijen',
#   'dit',
#   'doen',
#   'kunnen'],
#  ['Maar',
#   'wanneer',
#   'zij',
#   'met',
#   'ons',
#   'in',
#   'hel',
#   'strijdperk',
#   'treedt',
#   'en',
#   'eene',
#   'inet',
#   'ons',
#   'en',
#   'tegen',
#   'ons',
#   'mede',
#   'striidvoerende',
#   'partij',
#   'wordt',
#   'zal',
#   'haar',
#   'oordeel',
#   'even',
#   'subjectief',
#   'en',
#   'eenzijdig',
#   'worden',
#   'als',
#   'het',
#   'onze'],
#  [],
#  [],
#  ['Voorde',
#   'vrouw',
#   'zelve',
#   'zou',
#   'vrees',
#   'ik',
#   'de',
#   'emancipatie',
#   'het',
#   'aan',
#   'den',
#   'man',
#   'gelijk',
#   'worden',
#   'niet',
#   'enkel',
#   'eene',
#   'teleurstelling',
#   'maar',
#   'eene',
#   'abdicatie',
#   'zijn'],
#  ['Zij',
#   'zal',
#   'voor',
#   'hare',
#   'eerzucht',
#   'boeten',
#   'door',
#   'het',
#   'verlies',
#   'van',
#   'haren',
#   'moreelen',
#   'invloed'],
#  ['Zij',
#   'is',
#   'een',
#   'man',
#   'in',
#   'vrouweijkleederen',
#   'geworden',
#   'die',
#   'voortaan',
#   'als',
#   'man',
#   'zal',
#   'beschouwd',
#   'en',
#   'behandeld',
#   'worden'],
#  ['Als',
#   'vrouw',
#   'heelt',
#   'zij',
#   'zich',
#   'gesupprimeerd',
#   'en',
#   'daardoor',
#   'het',
#   'regt',
#   'verloren',
#   'met',
#   'de',
#   'égards',
#   'aan',
#   'de',
#   'vrouw',
#   'verschuldigd',
#   'bejegend',
#   'te',
#   'worden',
#   'De',
#   'karikatuur',
#   'der',
#   'niet',
#   'geëmancipeerde',
#   'vrouw',
#   'zoo',
#   'als',
#   'hare',
#   'emancipatoi',
#   's',
#   'men',
#   'zou',
#   'mogen',
#   'zeggen',
#   'hare',
#   'abolitionisten',
#   'haar',
#   'schilderen',
#   'tieem',
#   'ik',
#   'niet',
#   'aan'],
#  ['De',
#   'niet',
#   'geëmancipeerde',
#   'vrouw',
#   'is',
#   'niet',
#   'enkel',
#   'in',
#   'de',
#   'wereld',
#   'om',
#   'kousen',
#   'te',
#   'stoppen',
#   'de',
#   'wascli',
#   'op',
#   'te',
#   'doen',
#   'en',
#   'voor',
#   'den',
#   'putte',
#   'zorgen'],
#  ['Hare',
#   'pligten',
#   'en',
#   'taak',
#   'vooral',
#   'ook',
#   'haar',
#   'invloed',
#   'als',
#   'huisvrouw',
#   'als',
#   'moeder',
#   'als',
#   'vriendin',
#   'gaan',
#   'veel',
#   'verder'],
#  ['Menig',
#   'grootman',
#   'heelt',
#   'zijne',
#   'grootheid',
#   'te',
#   'danken',
#   'gehad',
#   'aan',
#   'den',
#   'geheimen',
#   'maar',
#   'veel',
#   'vermogenden',
#   'invloed',
#   'van',
#   'eene',
#   'verstandige',
#   'moeder',
#   'en',
#   'eene',
#   'verstandige',
#   'vrouw',
#   'en',
#   'ik',
#   'geloof',
#   'da',
#   't',
#   'verstandige',
#   'vrouwen',
#   'zich',
#   'die',
#   'werkelijke',
#   'magt',
#   'zeer',
#   'wel',
#   'bewust',
#   'zijn',
#   'en',
#   'volstrekt',
#   'niet',
#   'Verkiezen',
#   'zullen',
#   'haar',
#   'in',
#   'te',
#   'ruilen',
#   'tegen',
#   'het',
#   'bedriegelijk',
#   'aanzien',
#   'dat',
#   'haar',
#   'de',
#   'uiloefening',
#   'van',
#   'publieke',
#   'regten',
#   'en',
#   'publiek',
#   'gezag',
#   'zou',
#   'geveu'],
#  ['Ik',
#   'ontken',
#   'gcenzins',
#   'dat',
#   'er',
#   'verschillende',
#   'betrekkingen',
#   'in',
#   'de',
#   'maatschappij',
#   'zijn',
#   'welke',
#   'vrouwen',
#   'even',
#   'goed',
#   'en',
#   'somwijlen',
#   'beter',
#   'dan',
#   'mannen',
#   'zouden',
#   'kunnen',
#   'vervullen',
#   'zonder',
#   'dat',
#   'zij',
#   'daarom',
#   'als',
#   'vrouwen',
#   'zouden',
#   'abdiceeren'],
#  ['Er',
#   'zijn',
#   'slagbooïnen',
#   'van',
#   'het',
#   'vooroordeel',
#   'welke',
#   'weggeruimd',
#   'moeten',
#   'worden'],
#  ['Maar',
#   'dit',
#   'heelt',
#   'met',
#   'de',
#   'paradox',
#   'van',
#   'de',
#   'emancipatie',
#   'der',
#   'vrouw'],
#  ['die',
#   'in',
#   'het',
#   'wezen',
#   'der',
#   'zaak',
#   'de',
#   'vrouw',
#   'afschaft',
#   'terwijl',
#   'zij',
#   'voorgeelt',
#   'haar',
#   'te',
#   'verheffen',
#   'niets',
#   'te',
#   'maken']]

# %%
## Remove punctuation - keep only alphabetical characters

no_punct = []
for index, row in df.iterrows():
  text = list(chain.from_iterable(row['tokenized'])) #chain.from_iterable unlists the sentence-word sublist structure
  npun = [word for word in text if word.isalpha()]
  no_punct.append(npun)

df['no_punct'] = no_punct

# Check one text  
df['no_punct'][10]
# Out:
# ['Onder',
#  'bovenstaand',
#  'opschrift',
#  'bevat',
#  'de',
#  'Arnli',
#  'Ct',
#  'het',
#  'volgende',
#  'ingezonden',
#  'stuk',
#  'Vergun',
#  'aan',
#  'eeneu',
#  'uwer',
#  'meest',
#  'bestendige',
#  'lezers',
#  'mijnheer',
#  'de',
#  'redacteur',
#  'u',
#  'de',
#  'redenen',
#  'op',
#  'te',
#  'geven',
#  'Waarom',
#  'hij',
#  'niet',
#  'kan',
#  'instemmen',
#  'met',
#  'hetgeen',
#  'gij',
#  'ia',
#  'uw',
#  'nummer',
#  'vau',
#  'Augustus',
#  'geschreven',
#  'liebt',
#  'over',
#  'de',
#  'emancipatie',
#  'der',
#  'vrouw',
#  'In',
#  'de',
#  'perste',
#  'plaats',
#  'is',
#  'dat',
#  'grootsch',
#  'klinkende',
#  'woord',
#  'emancipatie',
#  'hier',
#  'wel',
#  'goed',
#  'gekozen',
#  'Ik',
#  'geloof',
#  'het',
#  'niet',
#  'Al',
#  'kennen',
#  'wij',
#  'ome',
#  'vrouwen',
#  'geeue',
#  'politieke',
#  'regten',
#  'toe',
#  'al',
#  'roepen',
#  'wij',
#  'haar',
#  'iet',
#  'in',
#  'de',
#  'raadzaal',
#  'en',
#  'in',
#  'de',
#  'pleitzaal',
#  'wij',
#  'beschouwen',
#  'en',
#  'behandelen',
#  'haar',
#  'daarom',
#  'niét',
#  'als',
#  'slaven',
#  'lijfeigenen',
#  'minderjarigen',
#  'of',
#  'onnouzelen',
#  'Do',
#  'invloed',
#  'der',
#  'vrouw',
#  'is',
#  'in',
#  'onze',
#  'maatschappij',
#  'zeer',
#  'sterkt',
#  'niet',
#  'enkel',
#  'iu',
#  'het',
#  'huiselijke',
#  'raam',
#  'ook',
#  'in',
#  'het',
#  'publieke',
#  'in',
#  'het',
#  'gansche',
#  'maatschappelijk',
#  'leven',
#  'eu',
#  'naar',
#  'mijne',
#  'overtuiging',
#  'is',
#  'die',
#  'invloed',
#  'der',
#  'vrouw',
#  'op',
#  'en',
#  'in',
#  'onze',
#  'maatschappij',
#  'juist',
#  'daarom',
#  'zoo',
#  'sterk',
#  'omdat',
#  'hij',
#  'een',
#  'moreele',
#  'd',
#  'i',
#  'een',
#  'middellijk',
#  'werkende',
#  'invloed',
#  'is',
#  'ïxDe',
#  'eisch',
#  'der',
#  'gelijkstelling',
#  'van',
#  'de',
#  'vrouw',
#  'met',
#  'den',
#  'man',
#  'rust',
#  'op',
#  'de',
#  'grondstelling',
#  'of',
#  'elgenlijk',
#  'op',
#  'de',
#  'onderstelling',
#  'dat',
#  'de',
#  'vrouw',
#  'in',
#  'alles',
#  'de',
#  'gelijke',
#  'van',
#  'den',
#  'man',
#  'en',
#  'zijn',
#  'evéubeeld',
#  'is',
#  'en',
#  'dat',
#  'dus',
#  'de',
#  'uitsluitende',
#  'toekenning',
#  'aan',
#  'de',
#  'mannen',
#  'van',
#  'zekere',
#  'reg',
#  'ten',
#  'en',
#  'der',
#  'uitoefening',
#  'van',
#  'zekere',
#  'bedrijven',
#  'eene',
#  'willekeurige',
#  'uit',
#  'vooroordeel',
#  'ontstane',
#  'en',
#  'in',
#  'stand',
#  'gehouden',
#  'bepaling',
#  'is',
#  'i',
#  'Deze',
#  'voorstelling',
#  'is',
#  'i',
#  'geheel',
#  'onjuist',
#  'omdat',
#  'de',
#  'grondstelling',
#  'en',
#  'onderstelling',
#  'op',
#  'welke',
#  'zij',
#  'rust',
#  'insgelijks',
#  'onjuist',
#  'is',
#  'De',
#  'vrouw',
#  'is',
#  'wel',
#  'degelijk',
#  'van',
#  'eene',
#  'andere',
#  'natuur',
#  'dan',
#  'de',
#  'man',
#  'en',
#  'een',
#  'niet',
#  'enkel',
#  'physisch',
#  'maar',
#  'ook',
#  'psychisch',
#  'van',
#  'hem',
#  'verschillend',
#  'wezen',
#  'Ik',
#  'beweer',
#  'daarmede',
#  'geenszins',
#  'dat',
#  'de',
#  'vrouw',
#  'de',
#  'mindere',
#  'van',
#  'den',
#  'man',
#  'is',
#  'dat',
#  'zij',
#  'verstandelijk',
#  'beneden',
#  'hein',
#  'staat',
#  'en',
#  'niet',
#  'voor',
#  'dezelfde',
#  'intellectueelo',
#  'ontwikkeling',
#  'als',
#  'hij',
#  'vatbaar',
#  'is',
#  'Ik',
#  'beweer',
#  'enkel',
#  'dit',
#  'dat',
#  'de',
#  'man',
#  'en',
#  'de',
#  'vrouw',
#  'wel',
#  'hoinogeene',
#  'maar',
#  'toch',
#  'van',
#  'natuur',
#  'verschillende',
#  'wezens',
#  'zijn',
#  'wezens',
#  'die',
#  'elk',
#  'met',
#  'een',
#  'bijzonderen',
#  'aanleg',
#  'en',
#  'eene',
#  'bijzondere',
#  'roeping',
#  'hunne',
#  'eigenaardige',
#  'taak',
#  'in',
#  'het',
#  'leven',
#  'te',
#  'vervullen',
#  'hebben',
#  'De',
#  'groote',
#  'staats',
#  'econoimsche',
#  'wet',
#  'der',
#  'zatncnwerkiiig',
#  'door',
#  'verdeclinri',
#  'van',
#  'den',
#  'arbeid',
#  'is',
#  'ook',
#  'dc',
#  'groote',
#  'natuur',
#  'economische',
#  'wet',
#  'de',
#  'wet',
#  'die',
#  'evenzeer',
#  'de',
#  'hoogste',
#  'diersoort',
#  'den',
#  'menseh',
#  'als',
#  'alle',
#  'andere',
#  'diersoorten',
#  'belieerscht',
#  'Door',
#  'hare',
#  'eigen',
#  'aardige',
#  'vrouwelijke',
#  'hoedanigheden',
#  'wordt',
#  'evenzeer',
#  'de',
#  'werkkring',
#  'der',
#  'vrouw',
#  'als',
#  'door',
#  'zijne',
#  'eigenaardige',
#  'mannelijke',
#  'hoedanigheden',
#  'die',
#  'van',
#  'den',
#  'man',
#  'bepaald',
#  'En',
#  'voor',
#  'de',
#  'vrouw',
#  'is',
#  'die',
#  'werkkring',
#  'zeer',
#  'duidelijk',
#  'aangewezen',
#  'het',
#  'huisselijke',
#  'en',
#  'particuliere',
#  'leven',
#  'het',
#  'leven',
#  'van',
#  'de',
#  'huisvrouw',
#  'en',
#  'de',
#  'huismoeder',
#  'Als',
#  'vriendin',
#  'raadgeefster',
#  'helpster',
#  'van',
#  'don',
#  'man',
#  'niet',
#  'als',
#  'zijn',
#  'gelijke',
#  'en',
#  'mededingster',
#  'werkt',
#  'zij',
#  'met',
#  'hem',
#  'tot',
#  'het',
#  'gemeenschappelijk',
#  'doel',
#  'des',
#  'levens',
#  'zamen',
#  'Is',
#  'zij',
#  'daarom',
#  'Vlinder',
#  'dan',
#  'de',
#  'man',
#  'omdat',
#  'zij',
#  'niet',
#  'op',
#  'de',
#  'beurs',
#  'handelt',
#  'niet',
#  'vonnissen',
#  'helpt',
#  'wijzen',
#  'en',
#  'wetteu',
#  'maken',
#  'geen',
#  'chirurgicale',
#  'operalien',
#  'doet',
#  'geeno',
#  'legers',
#  'aanvoert',
#  'en',
#  'geene',
#  'vloten',
#  'kommandccrt',
#  'Aan',
#  'de',
#  'vrouwen',
#  'politieke',
#  'regten',
#  'te',
#  'willen',
#  'toekennen',
#  'eu',
#  'haar',
#  'in',
#  'de',
#  'raadzaal',
#  'en',
#  'in',
#  'de',
#  'pleitzaal',
#  'te',
#  'roGpen',
#  'omdat',
#  'de',
#  'mannen',
#  'politieke',
#  'regten',
#  'hebben',
#  'en',
#  'in',
#  'die',
#  'zalen',
#  'optreden',
#  'is',
#  'dunkt',
#  'mij',
#  'eene',
#  'onlogische',
#  'en',
#  'valsche',
#  'gelijkheids',
#  'theorie',
#  'Do',
#  'toekenning',
#  'dier',
#  'reglcn',
#  'kan',
#  'ook',
#  'voor',
#  'de',
#  'vrouwen',
#  'alleen',
#  'gemotiveerd',
#  'worden',
#  'door',
#  'hetzelfde',
#  'motiet',
#  'waardoor',
#  'het',
#  'bij',
#  'de',
#  'mannen',
#  'gemotiveerd',
#  'wordt',
#  'door',
#  'de',
#  'eisohen',
#  'van',
#  'het',
#  'publiek',
#  'belang',
#  'Een',
#  'publiek',
#  'regt',
#  'behoort',
#  'niet',
#  'te',
#  'worden',
#  'toegekend',
#  'om',
#  'de',
#  'personen',
#  'te',
#  'believen',
#  'aan',
#  'wie',
#  'men',
#  'het',
#  'toekent',
#  'maar',
#  'omdat',
#  'het',
#  'algemeen',
#  'belang',
#  'die',
#  'toekenning',
#  'aan',
#  'deze',
#  'personen',
#  'eischt',
#  'Eene',
#  'uitbreiding',
#  'van',
#  'het',
#  'stemregt',
#  'b',
#  'v',
#  'is',
#  'alleen',
#  'dan',
#  'gemotiveerd',
#  'wanneer',
#  'men',
#  'aantoont',
#  'dat',
#  'in',
#  'het',
#  'algemeen',
#  'belang',
#  'nieuwe',
#  'categorien',
#  'van',
#  'kiezers',
#  'aan',
#  'de',
#  'beslaande',
#  'JBehooren',
#  'toegevoegd',
#  'te',
#  'worden',
#  'ii',
#  'Op',
#  'dit',
#  'standpunt',
#  'moet',
#  'men',
#  'zich',
#  'plaatsen',
#  'om',
#  'bet',
#  'onderwerp',
#  'van',
#  'de',
#  'zoogenaamde',
#  'emancipatie',
#  'der',
#  'vrouw',
#  'juist',
#  'te',
#  'kunnen',
#  'beoordeelen',
#  'Is',
#  'do',
#  'regtstreeksche',
#  'deelneming',
#  'der',
#  'vrouwen',
#  'aan',
#  'het',
#  'publiek',
#  'leven',
#  'een',
#  'eisch',
#  'van',
#  'algemeen',
#  'belang',
#  'Met',
#  'andere',
#  'woorden',
#  'wordt',
#  'het',
#  'algemeen',
#  'belang',
#  'piet',
#  'of',
#  'niet',
#  'folleilig',
#  'behartigd',
#  'wanneer',
#  'men',
#  'alleen',
#  'de',
#  'mannen',
#  'tot',
#  'reglstreeksche',
#  'deelneming',
#  'in',
#  'het',
#  'publiek',
#  'leven',
#  'reepte',
#  'Op',
#  'beide',
#  'vragen',
#  'antwoord',
#  'ik',
#  'ontkennend',
#  'B',
#  'vrouwen',
#  'iu',
#  'liet',
#  'publieke',
#  'leven',
#  'te',
#  'trekken',
#  'is',
#  'I',
#  'haart',
#  'onttrekken',
#  'aan',
#  'liet',
#  'h',
#  'uissel',
#  'ij',
#  'k',
#  'leven',
#  'is',
#  'y',
#  'haar',
#  'iriid',
#  'dellijke',
#  'morec',
#  'e',
#  'invloed',
#  'vervangen',
#  'door',
#  'ëëa',
#  'regt',
#  'treeksohen',
#  'imtcrieeleh',
#  'io',
#  'óe',
#  'l',
#  'En',
#  'hierin',
#  'zie',
#  'ik',
#  'een',
#  'groot',
#  'gevaar',
#  'voor',
#  'de',
#  'maatsebappij',
#  'De',
#  'vrouw',
#  'zal',
#  'daardoor',
#  'van',
#  'de',
#  'raad',
#  'geefster',
#  'des',
#  'mans',
#  'zijne',
#  'mededingster',
#  'worden',
#  'zij',
#  'zal',
#  'in',
#  'het',
#  'publieke',
#  'leven',
#  'even',
#  'dikwijls',
#  'tegen',
#  'hem',
#  'over',
#  'al',
#  'naast',
#  'hem',
#  'staan',
#  'Zij',
#  'zal',
#  'daardoor',
#  'aan',
#  'gezag',
#  'kunnen',
#  'winnen',
#  'maar',
#  'in',
#  'gelijke',
#  'mate',
#  'haren',
#  'invloed',
#  'op',
#  'hein',
#  'verliezen',
#  'Wanneer',
#  'de',
#  'vrouw',
#  'gelijk',
#  'thans',
#  'zelve',
#  'buiten',
#  'het',
#  'strijdperk',
#  'der',
#  'meeinngeu',
#  'slaat',
#  'is',
#  'haar',
#  'oordeel',
#  'over',
#  'hetgeen',
#  'daarin',
#  'voorvalt',
#  'meestal',
#  'een',
#  'objectiet',
#  'oordeel',
#  'Omdat',
#  'zij',
#  'geene',
#  'partij',
#  'in',
#  'het',
#  'geschil',
#  'is',
#  'beoordeelt',
#  'zij',
#  'de',
#  'laken',
#  'dikwijls',
#  'onzijdigcr',
#  'dan',
#  'wij',
#  'strijdvoerende',
#  'partijen',
#  'dit',
#  'doen',
#  'kunnen',
#  'Maar',
#  'wanneer',
#  'zij',
#  'met',
#  'ons',
#  'in',
#  'hel',
#  'strijdperk',
#  'treedt',
#  'en',
#  'eene',
#  'inet',
#  'ons',
#  'en',
#  'tegen',
#  'ons',
#  'mede',
#  'striidvoerende',
#  'partij',
#  'wordt',
#  'zal',
#  'haar',
#  'oordeel',
#  'even',
#  'subjectief',
#  'en',
#  'eenzijdig',
#  'worden',
#  'als',
#  'het',
#  'onze',
#  'Voorde',
#  'vrouw',
#  'zelve',
#  'zou',
#  'vrees',
#  'ik',
#  'de',
#  'emancipatie',
#  'het',
#  'aan',
#  'den',
#  'man',
#  'gelijk',
#  'worden',
#  'niet',
#  'enkel',
#  'eene',
#  'teleurstelling',
#  'maar',
#  'eene',
#  'abdicatie',
#  'zijn',
#  'Zij',
#  'zal',
#  'voor',
#  'hare',
#  'eerzucht',
#  'boeten',
#  'door',
#  'het',
#  'verlies',
#  'van',
#  'haren',
#  'moreelen',
#  'invloed',
#  'Zij',
#  'is',
#  'een',
#  'man',
#  'in',
#  'vrouweijkleederen',
#  'geworden',
#  'die',
#  'voortaan',
#  'als',
#  'man',
#  'zal',
#  'beschouwd',
#  'en',
#  'behandeld',
#  'worden',
#  'Als',
#  'vrouw',
#  'heelt',
#  'zij',
#  'zich',
#  'gesupprimeerd',
#  'en',
#  'daardoor',
#  'het',
#  'regt',
#  'verloren',
#  'met',
#  'de',
#  'égards',
#  'aan',
#  'de',
#  'vrouw',
#  'verschuldigd',
#  'bejegend',
#  'te',
#  'worden',
#  'De',
#  'karikatuur',
#  'der',
#  'niet',
#  'geëmancipeerde',
#  'vrouw',
#  'zoo',
#  'als',
#  'hare',
#  'emancipatoi',
#  's',
#  'men',
#  'zou',
#  'mogen',
#  'zeggen',
#  'hare',
#  'abolitionisten',
#  'haar',
#  'schilderen',
#  'tieem',
#  'ik',
#  'niet',
#  'aan',
#  'De',
#  'niet',
#  'geëmancipeerde',
#  'vrouw',
#  'is',
#  'niet',
#  'enkel',
#  'in',
#  'de',
#  'wereld',
#  'om',
#  'kousen',
#  'te',
#  'stoppen',
#  'de',
#  'wascli',
#  'op',
#  'te',
#  'doen',
#  'en',
#  'voor',
#  'den',
#  'putte',
#  'zorgen',
#  'Hare',
#  'pligten',
#  'en',
#  'taak',
#  'vooral',
#  'ook',
#  'haar',
#  'invloed',
#  'als',
#  'huisvrouw',
#  'als',
#  'moeder',
#  'als',
#  'vriendin',
#  'gaan',
#  'veel',
#  'verder',
#  'Menig',
#  'grootman',
#  'heelt',
#  'zijne',
#  'grootheid',
#  'te',
#  'danken',
#  'gehad',
#  'aan',
#  'den',
#  'geheimen',
#  'maar',
#  'veel',
#  'vermogenden',
#  'invloed',
#  'van',
#  'eene',
#  'verstandige',
#  'moeder',
#  'en',
#  'eene',
#  'verstandige',
#  'vrouw',
#  'en',
#  'ik',
#  'geloof',
#  'da',
#  't',
#  'verstandige',
#  'vrouwen',
#  'zich',
#  'die',
#  'werkelijke',
#  'magt',
#  'zeer',
#  'wel',
#  'bewust',
#  'zijn',
#  'en',
#  'volstrekt',
#  'niet',
#  'Verkiezen',
#  'zullen',
#  ...]

# %%
## Make lowercase
lowercase = []
for index, row in df.iterrows():
  text = row['no_punct']
  lc = [w.lower() for w in text]
  lowercase.append(lc)

df['lowercase'] = lowercase

# Check one text  
df['lowercase'][10]
# Out:
# ['onder',
#  'bovenstaand',
#  'opschrift',
#  'bevat',
#  'de',
#  'arnli',
#  'ct',
#  'het',
#  'volgende',
#  'ingezonden',
#  'stuk',
#  'vergun',
#  'aan',
#  'eeneu',
#  'uwer',
#  'meest',
#  'bestendige',
#  'lezers',
#  'mijnheer',
#  'de',
#  'redacteur',
#  'u',
#  'de',
#  'redenen',
#  'op',
#  'te',
#  'geven',
#  'waarom',
#  'hij',
#  'niet',
#  'kan',
#  'instemmen',
#  'met',
#  'hetgeen',
#  'gij',
#  'ia',
#  'uw',
#  'nummer',
#  'vau',
#  'augustus',
#  'geschreven',
#  'liebt',
#  'over',
#  'de',
#  'emancipatie',
#  'der',
#  'vrouw',
#  'in',
#  'de',
#  'perste',
#  'plaats',
#  'is',
#  'dat',
#  'grootsch',
#  'klinkende',
#  'woord',
#  'emancipatie',
#  'hier',
#  'wel',
#  'goed',
#  'gekozen',
#  'ik',
#  'geloof',
#  'het',
#  'niet',
#  'al',
#  'kennen',
#  'wij',
#  'ome',
#  'vrouwen',
#  'geeue',
#  'politieke',
#  'regten',
#  'toe',
#  'al',
#  'roepen',
#  'wij',
#  'haar',
#  'iet',
#  'in',
#  'de',
#  'raadzaal',
#  'en',
#  'in',
#  'de',
#  'pleitzaal',
#  'wij',
#  'beschouwen',
#  'en',
#  'behandelen',
#  'haar',
#  'daarom',
#  'niét',
#  'als',
#  'slaven',
#  'lijfeigenen',
#  'minderjarigen',
#  'of',
#  'onnouzelen',
#  'do',
#  'invloed',
#  'der',
#  'vrouw',
#  'is',
#  'in',
#  'onze',
#  'maatschappij',
#  'zeer',
#  'sterkt',
#  'niet',
#  'enkel',
#  'iu',
#  'het',
#  'huiselijke',
#  'raam',
#  'ook',
#  'in',
#  'het',
#  'publieke',
#  'in',
#  'het',
#  'gansche',
#  'maatschappelijk',
#  'leven',
#  'eu',
#  'naar',
#  'mijne',
#  'overtuiging',
#  'is',
#  'die',
#  'invloed',
#  'der',
#  'vrouw',
#  'op',
#  'en',
#  'in',
#  'onze',
#  'maatschappij',
#  'juist',
#  'daarom',
#  'zoo',
#  'sterk',
#  'omdat',
#  'hij',
#  'een',
#  'moreele',
#  'd',
#  'i',
#  'een',
#  'middellijk',
#  'werkende',
#  'invloed',
#  'is',
#  'ïxde',
#  'eisch',
#  'der',
#  'gelijkstelling',
#  'van',
#  'de',
#  'vrouw',
#  'met',
#  'den',
#  'man',
#  'rust',
#  'op',
#  'de',
#  'grondstelling',
#  'of',
#  'elgenlijk',
#  'op',
#  'de',
#  'onderstelling',
#  'dat',
#  'de',
#  'vrouw',
#  'in',
#  'alles',
#  'de',
#  'gelijke',
#  'van',
#  'den',
#  'man',
#  'en',
#  'zijn',
#  'evéubeeld',
#  'is',
#  'en',
#  'dat',
#  'dus',
#  'de',
#  'uitsluitende',
#  'toekenning',
#  'aan',
#  'de',
#  'mannen',
#  'van',
#  'zekere',
#  'reg',
#  'ten',
#  'en',
#  'der',
#  'uitoefening',
#  'van',
#  'zekere',
#  'bedrijven',
#  'eene',
#  'willekeurige',
#  'uit',
#  'vooroordeel',
#  'ontstane',
#  'en',
#  'in',
#  'stand',
#  'gehouden',
#  'bepaling',
#  'is',
#  'i',
#  'deze',
#  'voorstelling',
#  'is',
#  'i',
#  'geheel',
#  'onjuist',
#  'omdat',
#  'de',
#  'grondstelling',
#  'en',
#  'onderstelling',
#  'op',
#  'welke',
#  'zij',
#  'rust',
#  'insgelijks',
#  'onjuist',
#  'is',
#  'de',
#  'vrouw',
#  'is',
#  'wel',
#  'degelijk',
#  'van',
#  'eene',
#  'andere',
#  'natuur',
#  'dan',
#  'de',
#  'man',
#  'en',
#  'een',
#  'niet',
#  'enkel',
#  'physisch',
#  'maar',
#  'ook',
#  'psychisch',
#  'van',
#  'hem',
#  'verschillend',
#  'wezen',
#  'ik',
#  'beweer',
#  'daarmede',
#  'geenszins',
#  'dat',
#  'de',
#  'vrouw',
#  'de',
#  'mindere',
#  'van',
#  'den',
#  'man',
#  'is',
#  'dat',
#  'zij',
#  'verstandelijk',
#  'beneden',
#  'hein',
#  'staat',
#  'en',
#  'niet',
#  'voor',
#  'dezelfde',
#  'intellectueelo',
#  'ontwikkeling',
#  'als',
#  'hij',
#  'vatbaar',
#  'is',
#  'ik',
#  'beweer',
#  'enkel',
#  'dit',
#  'dat',
#  'de',
#  'man',
#  'en',
#  'de',
#  'vrouw',
#  'wel',
#  'hoinogeene',
#  'maar',
#  'toch',
#  'van',
#  'natuur',
#  'verschillende',
#  'wezens',
#  'zijn',
#  'wezens',
#  'die',
#  'elk',
#  'met',
#  'een',
#  'bijzonderen',
#  'aanleg',
#  'en',
#  'eene',
#  'bijzondere',
#  'roeping',
#  'hunne',
#  'eigenaardige',
#  'taak',
#  'in',
#  'het',
#  'leven',
#  'te',
#  'vervullen',
#  'hebben',
#  'de',
#  'groote',
#  'staats',
#  'econoimsche',
#  'wet',
#  'der',
#  'zatncnwerkiiig',
#  'door',
#  'verdeclinri',
#  'van',
#  'den',
#  'arbeid',
#  'is',
#  'ook',
#  'dc',
#  'groote',
#  'natuur',
#  'economische',
#  'wet',
#  'de',
#  'wet',
#  'die',
#  'evenzeer',
#  'de',
#  'hoogste',
#  'diersoort',
#  'den',
#  'menseh',
#  'als',
#  'alle',
#  'andere',
#  'diersoorten',
#  'belieerscht',
#  'door',
#  'hare',
#  'eigen',
#  'aardige',
#  'vrouwelijke',
#  'hoedanigheden',
#  'wordt',
#  'evenzeer',
#  'de',
#  'werkkring',
#  'der',
#  'vrouw',
#  'als',
#  'door',
#  'zijne',
#  'eigenaardige',
#  'mannelijke',
#  'hoedanigheden',
#  'die',
#  'van',
#  'den',
#  'man',
#  'bepaald',
#  'en',
#  'voor',
#  'de',
#  'vrouw',
#  'is',
#  'die',
#  'werkkring',
#  'zeer',
#  'duidelijk',
#  'aangewezen',
#  'het',
#  'huisselijke',
#  'en',
#  'particuliere',
#  'leven',
#  'het',
#  'leven',
#  'van',
#  'de',
#  'huisvrouw',
#  'en',
#  'de',
#  'huismoeder',
#  'als',
#  'vriendin',
#  'raadgeefster',
#  'helpster',
#  'van',
#  'don',
#  'man',
#  'niet',
#  'als',
#  'zijn',
#  'gelijke',
#  'en',
#  'mededingster',
#  'werkt',
#  'zij',
#  'met',
#  'hem',
#  'tot',
#  'het',
#  'gemeenschappelijk',
#  'doel',
#  'des',
#  'levens',
#  'zamen',
#  'is',
#  'zij',
#  'daarom',
#  'vlinder',
#  'dan',
#  'de',
#  'man',
#  'omdat',
#  'zij',
#  'niet',
#  'op',
#  'de',
#  'beurs',
#  'handelt',
#  'niet',
#  'vonnissen',
#  'helpt',
#  'wijzen',
#  'en',
#  'wetteu',
#  'maken',
#  'geen',
#  'chirurgicale',
#  'operalien',
#  'doet',
#  'geeno',
#  'legers',
#  'aanvoert',
#  'en',
#  'geene',
#  'vloten',
#  'kommandccrt',
#  'aan',
#  'de',
#  'vrouwen',
#  'politieke',
#  'regten',
#  'te',
#  'willen',
#  'toekennen',
#  'eu',
#  'haar',
#  'in',
#  'de',
#  'raadzaal',
#  'en',
#  'in',
#  'de',
#  'pleitzaal',
#  'te',
#  'rogpen',
#  'omdat',
#  'de',
#  'mannen',
#  'politieke',
#  'regten',
#  'hebben',
#  'en',
#  'in',
#  'die',
#  'zalen',
#  'optreden',
#  'is',
#  'dunkt',
#  'mij',
#  'eene',
#  'onlogische',
#  'en',
#  'valsche',
#  'gelijkheids',
#  'theorie',
#  'do',
#  'toekenning',
#  'dier',
#  'reglcn',
#  'kan',
#  'ook',
#  'voor',
#  'de',
#  'vrouwen',
#  'alleen',
#  'gemotiveerd',
#  'worden',
#  'door',
#  'hetzelfde',
#  'motiet',
#  'waardoor',
#  'het',
#  'bij',
#  'de',
#  'mannen',
#  'gemotiveerd',
#  'wordt',
#  'door',
#  'de',
#  'eisohen',
#  'van',
#  'het',
#  'publiek',
#  'belang',
#  'een',
#  'publiek',
#  'regt',
#  'behoort',
#  'niet',
#  'te',
#  'worden',
#  'toegekend',
#  'om',
#  'de',
#  'personen',
#  'te',
#  'believen',
#  'aan',
#  'wie',
#  'men',
#  'het',
#  'toekent',
#  'maar',
#  'omdat',
#  'het',
#  'algemeen',
#  'belang',
#  'die',
#  'toekenning',
#  'aan',
#  'deze',
#  'personen',
#  'eischt',
#  'eene',
#  'uitbreiding',
#  'van',
#  'het',
#  'stemregt',
#  'b',
#  'v',
#  'is',
#  'alleen',
#  'dan',
#  'gemotiveerd',
#  'wanneer',
#  'men',
#  'aantoont',
#  'dat',
#  'in',
#  'het',
#  'algemeen',
#  'belang',
#  'nieuwe',
#  'categorien',
#  'van',
#  'kiezers',
#  'aan',
#  'de',
#  'beslaande',
#  'jbehooren',
#  'toegevoegd',
#  'te',
#  'worden',
#  'ii',
#  'op',
#  'dit',
#  'standpunt',
#  'moet',
#  'men',
#  'zich',
#  'plaatsen',
#  'om',
#  'bet',
#  'onderwerp',
#  'van',
#  'de',
#  'zoogenaamde',
#  'emancipatie',
#  'der',
#  'vrouw',
#  'juist',
#  'te',
#  'kunnen',
#  'beoordeelen',
#  'is',
#  'do',
#  'regtstreeksche',
#  'deelneming',
#  'der',
#  'vrouwen',
#  'aan',
#  'het',
#  'publiek',
#  'leven',
#  'een',
#  'eisch',
#  'van',
#  'algemeen',
#  'belang',
#  'met',
#  'andere',
#  'woorden',
#  'wordt',
#  'het',
#  'algemeen',
#  'belang',
#  'piet',
#  'of',
#  'niet',
#  'folleilig',
#  'behartigd',
#  'wanneer',
#  'men',
#  'alleen',
#  'de',
#  'mannen',
#  'tot',
#  'reglstreeksche',
#  'deelneming',
#  'in',
#  'het',
#  'publiek',
#  'leven',
#  'reepte',
#  'op',
#  'beide',
#  'vragen',
#  'antwoord',
#  'ik',
#  'ontkennend',
#  'b',
#  'vrouwen',
#  'iu',
#  'liet',
#  'publieke',
#  'leven',
#  'te',
#  'trekken',
#  'is',
#  'i',
#  'haart',
#  'onttrekken',
#  'aan',
#  'liet',
#  'h',
#  'uissel',
#  'ij',
#  'k',
#  'leven',
#  'is',
#  'y',
#  'haar',
#  'iriid',
#  'dellijke',
#  'morec',
#  'e',
#  'invloed',
#  'vervangen',
#  'door',
#  'ëëa',
#  'regt',
#  'treeksohen',
#  'imtcrieeleh',
#  'io',
#  'óe',
#  'l',
#  'en',
#  'hierin',
#  'zie',
#  'ik',
#  'een',
#  'groot',
#  'gevaar',
#  'voor',
#  'de',
#  'maatsebappij',
#  'de',
#  'vrouw',
#  'zal',
#  'daardoor',
#  'van',
#  'de',
#  'raad',
#  'geefster',
#  'des',
#  'mans',
#  'zijne',
#  'mededingster',
#  'worden',
#  'zij',
#  'zal',
#  'in',
#  'het',
#  'publieke',
#  'leven',
#  'even',
#  'dikwijls',
#  'tegen',
#  'hem',
#  'over',
#  'al',
#  'naast',
#  'hem',
#  'staan',
#  'zij',
#  'zal',
#  'daardoor',
#  'aan',
#  'gezag',
#  'kunnen',
#  'winnen',
#  'maar',
#  'in',
#  'gelijke',
#  'mate',
#  'haren',
#  'invloed',
#  'op',
#  'hein',
#  'verliezen',
#  'wanneer',
#  'de',
#  'vrouw',
#  'gelijk',
#  'thans',
#  'zelve',
#  'buiten',
#  'het',
#  'strijdperk',
#  'der',
#  'meeinngeu',
#  'slaat',
#  'is',
#  'haar',
#  'oordeel',
#  'over',
#  'hetgeen',
#  'daarin',
#  'voorvalt',
#  'meestal',
#  'een',
#  'objectiet',
#  'oordeel',
#  'omdat',
#  'zij',
#  'geene',
#  'partij',
#  'in',
#  'het',
#  'geschil',
#  'is',
#  'beoordeelt',
#  'zij',
#  'de',
#  'laken',
#  'dikwijls',
#  'onzijdigcr',
#  'dan',
#  'wij',
#  'strijdvoerende',
#  'partijen',
#  'dit',
#  'doen',
#  'kunnen',
#  'maar',
#  'wanneer',
#  'zij',
#  'met',
#  'ons',
#  'in',
#  'hel',
#  'strijdperk',
#  'treedt',
#  'en',
#  'eene',
#  'inet',
#  'ons',
#  'en',
#  'tegen',
#  'ons',
#  'mede',
#  'striidvoerende',
#  'partij',
#  'wordt',
#  'zal',
#  'haar',
#  'oordeel',
#  'even',
#  'subjectief',
#  'en',
#  'eenzijdig',
#  'worden',
#  'als',
#  'het',
#  'onze',
#  'voorde',
#  'vrouw',
#  'zelve',
#  'zou',
#  'vrees',
#  'ik',
#  'de',
#  'emancipatie',
#  'het',
#  'aan',
#  'den',
#  'man',
#  'gelijk',
#  'worden',
#  'niet',
#  'enkel',
#  'eene',
#  'teleurstelling',
#  'maar',
#  'eene',
#  'abdicatie',
#  'zijn',
#  'zij',
#  'zal',
#  'voor',
#  'hare',
#  'eerzucht',
#  'boeten',
#  'door',
#  'het',
#  'verlies',
#  'van',
#  'haren',
#  'moreelen',
#  'invloed',
#  'zij',
#  'is',
#  'een',
#  'man',
#  'in',
#  'vrouweijkleederen',
#  'geworden',
#  'die',
#  'voortaan',
#  'als',
#  'man',
#  'zal',
#  'beschouwd',
#  'en',
#  'behandeld',
#  'worden',
#  'als',
#  'vrouw',
#  'heelt',
#  'zij',
#  'zich',
#  'gesupprimeerd',
#  'en',
#  'daardoor',
#  'het',
#  'regt',
#  'verloren',
#  'met',
#  'de',
#  'égards',
#  'aan',
#  'de',
#  'vrouw',
#  'verschuldigd',
#  'bejegend',
#  'te',
#  'worden',
#  'de',
#  'karikatuur',
#  'der',
#  'niet',
#  'geëmancipeerde',
#  'vrouw',
#  'zoo',
#  'als',
#  'hare',
#  'emancipatoi',
#  's',
#  'men',
#  'zou',
#  'mogen',
#  'zeggen',
#  'hare',
#  'abolitionisten',
#  'haar',
#  'schilderen',
#  'tieem',
#  'ik',
#  'niet',
#  'aan',
#  'de',
#  'niet',
#  'geëmancipeerde',
#  'vrouw',
#  'is',
#  'niet',
#  'enkel',
#  'in',
#  'de',
#  'wereld',
#  'om',
#  'kousen',
#  'te',
#  'stoppen',
#  'de',
#  'wascli',
#  'op',
#  'te',
#  'doen',
#  'en',
#  'voor',
#  'den',
#  'putte',
#  'zorgen',
#  'hare',
#  'pligten',
#  'en',
#  'taak',
#  'vooral',
#  'ook',
#  'haar',
#  'invloed',
#  'als',
#  'huisvrouw',
#  'als',
#  'moeder',
#  'als',
#  'vriendin',
#  'gaan',
#  'veel',
#  'verder',
#  'menig',
#  'grootman',
#  'heelt',
#  'zijne',
#  'grootheid',
#  'te',
#  'danken',
#  'gehad',
#  'aan',
#  'den',
#  'geheimen',
#  'maar',
#  'veel',
#  'vermogenden',
#  'invloed',
#  'van',
#  'eene',
#  'verstandige',
#  'moeder',
#  'en',
#  'eene',
#  'verstandige',
#  'vrouw',
#  'en',
#  'ik',
#  'geloof',
#  'da',
#  't',
#  'verstandige',
#  'vrouwen',
#  'zich',
#  'die',
#  'werkelijke',
#  'magt',
#  'zeer',
#  'wel',
#  'bewust',
#  'zijn',
#  'en',
#  'volstrekt',
#  'niet',
#  'verkiezen',
#  'zullen',
#  ...]

# %%
# Remove stopwords
stop_words = set(stopwords.words('dutch'))
# Keep personal pronouns
stop_words.remove("haar")
stop_words.remove("hem")
stop_words.remove("hij")
stop_words.remove("ze")
stop_words.remove("zij")
stop_words.remove("moet")
stop_words.remove("mijn")

sw = []
for index, row in df.iterrows():
  text = row['lowercase']
  swords = [w for w in text if not w in stop_words]
  sw.append(swords)

df['stopwords'] = sw

# Check one text  
df['stopwords'][10]
# Out:
# ['bovenstaand',
#  'opschrift',
#  'bevat',
#  'arnli',
#  'ct',
#  'volgende',
#  'ingezonden',
#  'stuk',
#  'vergun',
#  'eeneu',
#  'uwer',
#  'meest',
#  'bestendige',
#  'lezers',
#  'mijnheer',
#  'redacteur',
#  'redenen',
#  'geven',
#  'waarom',
#  'hij',
#  'instemmen',
#  'hetgeen',
#  'gij',
#  'ia',
#  'nummer',
#  'vau',
#  'augustus',
#  'geschreven',
#  'liebt',
#  'emancipatie',
#  'vrouw',
#  'perste',
#  'plaats',
#  'grootsch',
#  'klinkende',
#  'woord',
#  'emancipatie',
#  'wel',
#  'goed',
#  'gekozen',
#  'geloof',
#  'kennen',
#  'wij',
#  'ome',
#  'vrouwen',
#  'geeue',
#  'politieke',
#  'regten',
#  'toe',
#  'roepen',
#  'wij',
#  'haar',
#  'iet',
#  'raadzaal',
#  'pleitzaal',
#  'wij',
#  'beschouwen',
#  'behandelen',
#  'haar',
#  'daarom',
#  'niét',
#  'slaven',
#  'lijfeigenen',
#  'minderjarigen',
#  'onnouzelen',
#  'do',
#  'invloed',
#  'vrouw',
#  'onze',
#  'maatschappij',
#  'zeer',
#  'sterkt',
#  'enkel',
#  'iu',
#  'huiselijke',
#  'raam',
#  'publieke',
#  'gansche',
#  'maatschappelijk',
#  'leven',
#  'eu',
#  'mijne',
#  'overtuiging',
#  'invloed',
#  'vrouw',
#  'onze',
#  'maatschappij',
#  'juist',
#  'daarom',
#  'zoo',
#  'sterk',
#  'hij',
#  'moreele',
#  'd',
#  'i',
#  'middellijk',
#  'werkende',
#  'invloed',
#  'ïxde',
#  'eisch',
#  'gelijkstelling',
#  'vrouw',
#  'den',
#  'man',
#  'rust',
#  'grondstelling',
#  'elgenlijk',
#  'onderstelling',
#  'vrouw',
#  'gelijke',
#  'den',
#  'man',
#  'evéubeeld',
#  'uitsluitende',
#  'toekenning',
#  'mannen',
#  'zekere',
#  'reg',
#  'ten',
#  'uitoefening',
#  'zekere',
#  'bedrijven',
#  'eene',
#  'willekeurige',
#  'vooroordeel',
#  'ontstane',
#  'stand',
#  'gehouden',
#  'bepaling',
#  'i',
#  'voorstelling',
#  'i',
#  'geheel',
#  'onjuist',
#  'grondstelling',
#  'onderstelling',
#  'welke',
#  'zij',
#  'rust',
#  'insgelijks',
#  'onjuist',
#  'vrouw',
#  'wel',
#  'degelijk',
#  'eene',
#  'natuur',
#  'man',
#  'enkel',
#  'physisch',
#  'psychisch',
#  'hem',
#  'verschillend',
#  'beweer',
#  'daarmede',
#  'geenszins',
#  'vrouw',
#  'mindere',
#  'den',
#  'man',
#  'zij',
#  'verstandelijk',
#  'beneden',
#  'hein',
#  'staat',
#  'dezelfde',
#  'intellectueelo',
#  'ontwikkeling',
#  'hij',
#  'vatbaar',
#  'beweer',
#  'enkel',
#  'man',
#  'vrouw',
#  'wel',
#  'hoinogeene',
#  'natuur',
#  'verschillende',
#  'wezens',
#  'wezens',
#  'elk',
#  'bijzonderen',
#  'aanleg',
#  'eene',
#  'bijzondere',
#  'roeping',
#  'hunne',
#  'eigenaardige',
#  'taak',
#  'leven',
#  'vervullen',
#  'groote',
#  'staats',
#  'econoimsche',
#  'wet',
#  'zatncnwerkiiig',
#  'verdeclinri',
#  'den',
#  'arbeid',
#  'dc',
#  'groote',
#  'natuur',
#  'economische',
#  'wet',
#  'wet',
#  'evenzeer',
#  'hoogste',
#  'diersoort',
#  'den',
#  'menseh',
#  'alle',
#  'diersoorten',
#  'belieerscht',
#  'hare',
#  'eigen',
#  'aardige',
#  'vrouwelijke',
#  'hoedanigheden',
#  'evenzeer',
#  'werkkring',
#  'vrouw',
#  'zijne',
#  'eigenaardige',
#  'mannelijke',
#  'hoedanigheden',
#  'den',
#  'man',
#  'bepaald',
#  'vrouw',
#  'werkkring',
#  'zeer',
#  'duidelijk',
#  'aangewezen',
#  'huisselijke',
#  'particuliere',
#  'leven',
#  'leven',
#  'huisvrouw',
#  'huismoeder',
#  'vriendin',
#  'raadgeefster',
#  'helpster',
#  'don',
#  'man',
#  'gelijke',
#  'mededingster',
#  'werkt',
#  'zij',
#  'hem',
#  'gemeenschappelijk',
#  'doel',
#  'des',
#  'levens',
#  'zamen',
#  'zij',
#  'daarom',
#  'vlinder',
#  'man',
#  'zij',
#  'beurs',
#  'handelt',
#  'vonnissen',
#  'helpt',
#  'wijzen',
#  'wetteu',
#  'maken',
#  'chirurgicale',
#  'operalien',
#  'doet',
#  'geeno',
#  'legers',
#  'aanvoert',
#  'geene',
#  'vloten',
#  'kommandccrt',
#  'vrouwen',
#  'politieke',
#  'regten',
#  'willen',
#  'toekennen',
#  'eu',
#  'haar',
#  'raadzaal',
#  'pleitzaal',
#  'rogpen',
#  'mannen',
#  'politieke',
#  'regten',
#  'zalen',
#  'optreden',
#  'dunkt',
#  'eene',
#  'onlogische',
#  'valsche',
#  'gelijkheids',
#  'theorie',
#  'do',
#  'toekenning',
#  'dier',
#  'reglcn',
#  'vrouwen',
#  'alleen',
#  'gemotiveerd',
#  'hetzelfde',
#  'motiet',
#  'waardoor',
#  'mannen',
#  'gemotiveerd',
#  'eisohen',
#  'publiek',
#  'belang',
#  'publiek',
#  'regt',
#  'behoort',
#  'toegekend',
#  'personen',
#  'believen',
#  'toekent',
#  'algemeen',
#  'belang',
#  'toekenning',
#  'personen',
#  'eischt',
#  'eene',
#  'uitbreiding',
#  'stemregt',
#  'b',
#  'v',
#  'alleen',
#  'gemotiveerd',
#  'wanneer',
#  'aantoont',
#  'algemeen',
#  'belang',
#  'nieuwe',
#  'categorien',
#  'kiezers',
#  'beslaande',
#  'jbehooren',
#  'toegevoegd',
#  'ii',
#  'standpunt',
#  'moet',
#  'plaatsen',
#  'bet',
#  'onderwerp',
#  'zoogenaamde',
#  'emancipatie',
#  'vrouw',
#  'juist',
#  'beoordeelen',
#  'do',
#  'regtstreeksche',
#  'deelneming',
#  'vrouwen',
#  'publiek',
#  'leven',
#  'eisch',
#  'algemeen',
#  'belang',
#  'woorden',
#  'algemeen',
#  'belang',
#  'piet',
#  'folleilig',
#  'behartigd',
#  'wanneer',
#  'alleen',
#  'mannen',
#  'reglstreeksche',
#  'deelneming',
#  'publiek',
#  'leven',
#  'reepte',
#  'beide',
#  'vragen',
#  'antwoord',
#  'ontkennend',
#  'b',
#  'vrouwen',
#  'iu',
#  'liet',
#  'publieke',
#  'leven',
#  'trekken',
#  'i',
#  'haart',
#  'onttrekken',
#  'liet',
#  'h',
#  'uissel',
#  'ij',
#  'k',
#  'leven',
#  'y',
#  'haar',
#  'iriid',
#  'dellijke',
#  'morec',
#  'e',
#  'invloed',
#  'vervangen',
#  'ëëa',
#  'regt',
#  'treeksohen',
#  'imtcrieeleh',
#  'io',
#  'óe',
#  'l',
#  'hierin',
#  'zie',
#  'groot',
#  'gevaar',
#  'maatsebappij',
#  'vrouw',
#  'daardoor',
#  'raad',
#  'geefster',
#  'des',
#  'mans',
#  'zijne',
#  'mededingster',
#  'zij',
#  'publieke',
#  'leven',
#  'even',
#  'dikwijls',
#  'hem',
#  'naast',
#  'hem',
#  'staan',
#  'zij',
#  'daardoor',
#  'gezag',
#  'winnen',
#  'gelijke',
#  'mate',
#  'haren',
#  'invloed',
#  'hein',
#  'verliezen',
#  'wanneer',
#  'vrouw',
#  'gelijk',
#  'thans',
#  'zelve',
#  'buiten',
#  'strijdperk',
#  'meeinngeu',
#  'slaat',
#  'haar',
#  'oordeel',
#  'hetgeen',
#  'daarin',
#  'voorvalt',
#  'meestal',
#  'objectiet',
#  'oordeel',
#  'zij',
#  'geene',
#  'partij',
#  'geschil',
#  'beoordeelt',
#  'zij',
#  'laken',
#  'dikwijls',
#  'onzijdigcr',
#  'wij',
#  'strijdvoerende',
#  'partijen',
#  'wanneer',
#  'zij',
#  'hel',
#  'strijdperk',
#  'treedt',
#  'eene',
#  'inet',
#  'mede',
#  'striidvoerende',
#  'partij',
#  'haar',
#  'oordeel',
#  'even',
#  'subjectief',
#  'eenzijdig',
#  'onze',
#  'voorde',
#  'vrouw',
#  'zelve',
#  'vrees',
#  'emancipatie',
#  'den',
#  'man',
#  'gelijk',
#  'enkel',
#  'eene',
#  'teleurstelling',
#  'eene',
#  'abdicatie',
#  'zij',
#  'hare',
#  'eerzucht',
#  'boeten',
#  'verlies',
#  'haren',
#  'moreelen',
#  'invloed',
#  'zij',
#  'man',
#  'vrouweijkleederen',
#  'geworden',
#  'voortaan',
#  'man',
#  'beschouwd',
#  'behandeld',
#  'vrouw',
#  'heelt',
#  'zij',
#  'gesupprimeerd',
#  'daardoor',
#  'regt',
#  'verloren',
#  'égards',
#  'vrouw',
#  'verschuldigd',
#  'bejegend',
#  'karikatuur',
#  'geëmancipeerde',
#  'vrouw',
#  'zoo',
#  'hare',
#  'emancipatoi',
#  's',
#  'mogen',
#  'zeggen',
#  'hare',
#  'abolitionisten',
#  'haar',
#  'schilderen',
#  'tieem',
#  'geëmancipeerde',
#  'vrouw',
#  'enkel',
#  'wereld',
#  'kousen',
#  'stoppen',
#  'wascli',
#  'den',
#  'putte',
#  'zorgen',
#  'hare',
#  'pligten',
#  'taak',
#  'vooral',
#  'haar',
#  'invloed',
#  'huisvrouw',
#  'moeder',
#  'vriendin',
#  'gaan',
#  'verder',
#  'menig',
#  'grootman',
#  'heelt',
#  'zijne',
#  'grootheid',
#  'danken',
#  'gehad',
#  'den',
#  'geheimen',
#  'vermogenden',
#  'invloed',
#  'eene',
#  'verstandige',
#  'moeder',
#  'eene',
#  'verstandige',
#  'vrouw',
#  'geloof',
#  'da',
#  't',
#  'verstandige',
#  'vrouwen',
#  'werkelijke',
#  'magt',
#  'zeer',
#  'wel',
#  'bewust',
#  'volstrekt',
#  'verkiezen',
#  'zullen',
#  'haar',
#  'ruilen',
#  'bedriegelijk',
#  'aanzien',
#  'haar',
#  'uiloefening',
#  'publieke',
#  'regten',
#  'publiek',
#  'gezag',
#  'geveu',
#  'ontken',
#  'gcenzins',
#  'verschillende',
#  'betrekkingen',
#  'maatschappij',
#  'welke',
#  'vrouwen',
#  'even',
#  'goed',
#  'somwijlen',
#  'beter',
#  'mannen',
#  'zouden',
#  'vervullen',
#  'zij',
#  'daarom',
#  'vrouwen',
#  'zouden',
#  'abdiceeren',
#  'slagbooïnen',
#  'vooroordeel',
#  'welke',
#  'weggeruimd',
#  'moeten',
#  'heelt',
#  'paradox',
#  'emancipatie',
#  'vrouw',
#  'zaak',
#  'vrouw',
#  'afschaft',
#  'terwijl',
#  'zij',
#  'voorgeelt',
#  'haar',
#  'verheffen',
#  'maken']

# %%
# Save relevant columns
df.info()
df_save = df.drop(["text", "sen_tokenized", "tokenized", "length", "no_punct","lowercase","index"], axis=1)
df_save.rename(columns = {'stopwords':'text'}, inplace = True)
df_save.info()

path = 'path to folder where to save data'+file_name+'_preprocessed.csv'
df_save.to_csv(path_or_buf=path, na_rep = 'NA', index_label=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200983 entries, 0 to 200983
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   level_0        200983 non-null  int64
#  1   index          200983 non-null  int64
#  2   type           200983 non-null  object
#  3   title          200950 non-null  object
#  4   papertitle     200983 non-null  object
#  5   date           200983 non-null  datetime64[ns]
#  6   text           200983 non-null  object
#  7   sen_tokenized  200983 non-null  object
#  8   tokenized      200983 non-null  object
#  9   length         200983 non-null  int64
#  10  no_punct       200983 non-null  object
#  11  lowercase      200983 non-null  object
#  12  stopwords      200983 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 26.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200983 entries, 0 to 200983
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   level_0     200983 non-null  int64
#  1   type        200983 non-null  object
#  2   title       200950 non-null  object
#  3   papertitle  200983 non-null  object
#  4   date        200983 non-null  datetime64[ns]
#  5   text        200983 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 15.7+ MB
